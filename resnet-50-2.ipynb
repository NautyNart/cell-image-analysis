# %%
import os, random, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import (f1_score, accuracy_score, cohen_kappa_score,
                             confusion_matrix, classification_report)
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
warnings.filterwarnings('ignore')

# CONFIG
PREPROCESSED_DIR = '/kaggle/input/datasets/eva233333/data3888-preprocessing2/'
OUT_DIR          = '/kaggle/working/'

SEED         = 42
NUM_EPOCHS   = 30
PATIENCE     = 5
BATCH_SIZE   = 64
NUM_CLASSES  = 3
IMG_SIZE_100 = 224
IMG_SIZE_50  = 140
DEVICE       = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

LR_HEAD   = 3e-4
LR_LAYER4 = 3e-5

CLASS_NAMES = ['Tumor', 'DCIS_1', 'DCIS_2']

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)


# LOAD DATASETS
# Strategy 1: leakage-free split → used for 100px and 50px experiments
# Strategy 2: original split + masked paths → used for masked experiment
master_s1  = pd.read_csv(PREPROCESSED_DIR + 'master_labels_s1.csv')
master_s2  = pd.read_csv(PREPROCESSED_DIR + 'master_labels_s2.csv')
norm_stats = pd.read_csv(PREPROCESSED_DIR + 'norm_stats.csv')
MEAN       = norm_stats['mean'].tolist()
STD        = norm_stats['std'].tolist()

print("Strategy 1 (100px / 50px CNN)")
print(f"Total: {len(master_s1):,}")
print(master_s1['split'].value_counts().to_string())
print("\nClass distribution:")
print(master_s1['label'].value_counts().to_string())

print("\nStrategy 2 (masked CNN)")
print(f"Total: {len(master_s2):,}")
print(master_s2['split'].value_counts().to_string())


# DATASET
def get_transforms(img_size):
    return transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=MEAN, std=STD),
    ])


MASK_KEEP_RATIO = 0.30
MASK_FILL       = np.array([123, 116, 103], dtype=np.uint8)

def apply_mask(img):
    arr    = np.array(img)
    h, w   = arr.shape[:2]
    cx, cy = w // 2, h // 2
    radius = int(min(h, w) * MASK_KEEP_RATIO)
    Y, X   = np.ogrid[:h, :w]
    inside = (X - cx) ** 2 + (Y - cy) ** 2 <= radius ** 2
    result = np.full_like(arr, fill_value=MASK_FILL)
    result[inside] = arr[inside]
    return Image.fromarray(result)


class CellDataset(Dataset):
    def __init__(self, df, split, use_100px=True, use_masked=False):
        self.df         = df[df['split'] == split].reset_index(drop=True)
        self.use_masked = use_masked
        self.path_col   = 'path_100' if use_100px else 'path_50'
        img_size        = IMG_SIZE_100 if use_100px else IMG_SIZE_50
        self.transform  = get_transforms(img_size)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row[self.path_col]).convert('RGB')
        if self.use_masked:
            img = apply_mask(img)
        img   = self.transform(img)
        label = torch.tensor(row['label'], dtype=torch.long)
        return img, label


def get_dataloaders(master_df, use_100px=True, use_masked=False):
    train_ds = CellDataset(master_df, 'train', use_100px, use_masked)
    val_ds   = CellDataset(master_df, 'val',   use_100px, use_masked)
    test_ds  = CellDataset(master_df, 'test',  use_100px, use_masked)
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                              num_workers=2, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                              num_workers=2, pin_memory=True)
    return train_loader, val_loader, test_loader


# Verify dataset sizes
print("\nStrategy 1 dataset sizes")
for px, flag in [('100px', True), ('50px', False)]:
    tr = CellDataset(master_s1, 'train', flag)
    va = CellDataset(master_s1, 'val',   flag)
    te = CellDataset(master_s1, 'test',  flag)
    print(f"  {px}: Train {len(tr):,} | Val {len(va):,} | Test {len(te):,}")

print("\nStrategy 2 dataset sizes (masked)")
tr_m = CellDataset(master_s2, 'train', use_100px=True, use_masked=True)
va_m = CellDataset(master_s2, 'val',   use_100px=True, use_masked=True)
te_m = CellDataset(master_s2, 'test',  use_100px=True, use_masked=True)
print(f"  masked 100px: Train {len(tr_m):,} | Val {len(va_m):,} | Test {len(te_m):,}")

# Quick batch shape check
sample_loader = DataLoader(CellDataset(master_s1, 'train', True), batch_size=4)
imgs, _       = next(iter(sample_loader))
print(f"\n  100px batch shape:  {imgs.shape}")   # [4, 3, 224, 224]

sample_loader_50 = DataLoader(CellDataset(master_s1, 'train', False), batch_size=4)
imgs_50, _       = next(iter(sample_loader_50))
print(f"  50px batch shape:   {imgs_50.shape}")  # [4, 3, 140, 140]

sample_loader_m = DataLoader(CellDataset(master_s2, 'train', True, True), batch_size=4)
imgs_m, _       = next(iter(sample_loader_m))
print(f"  masked batch shape: {imgs_m.shape}")   # [4, 3, 224, 224]


# MODEL — ResNet-50
def build_model():
    model    = models.resnet50(weights='IMAGENET1K_V2')
    model.fc = nn.Sequential(
        nn.Dropout(p=0.5),
        nn.Linear(2048, NUM_CLASSES)
    )
    return model.to(DEVICE)


LR_HEAD   = 3e-4
LR_LAYER4 = 3e-5

def get_optimizer(model):
    for param in model.parameters():
        param.requires_grad = False
    for param in model.layer4.parameters():
        param.requires_grad = True
    for param in model.fc.parameters():
        param.requires_grad = True
    return torch.optim.Adam([
        {'params': model.layer4.parameters(), 'lr': LR_LAYER4},
        {'params': model.fc.parameters(),     'lr': LR_HEAD},
    ], weight_decay=1e-2)


# TRAINING AND EVALUATION
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss, all_preds, all_labels = 0.0, [], []
    for imgs, labels in loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss    = criterion(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * imgs.size(0)
        preds = outputs.argmax(dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    avg_loss = total_loss / len(loader.dataset)
    acc      = accuracy_score(all_labels, all_preds)
    f1       = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    return avg_loss, acc, f1


def evaluate(model, loader, criterion):
    model.eval()
    total_loss, all_preds, all_labels = 0.0, [], []
    with torch.no_grad():
        for imgs, labels in loader:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            outputs = model(imgs)
            loss    = criterion(outputs, labels)
            total_loss += loss.item() * imgs.size(0)
            preds = outputs.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    avg_loss = total_loss / len(loader.dataset)
    acc      = accuracy_score(all_labels, all_preds)
    f1       = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    return avg_loss, acc, f1, all_preds, all_labels


# MAIN TRAINING LOOP
def train_cnn(master_df, use_100px=True, use_masked=False, tag=None):
    if tag is None:
        tag = 'masked' if use_masked else ('100px' if use_100px else '50px')

    print(f"Training CNN — {tag}")

    train_loader, val_loader, test_loader = get_dataloaders(
        master_df, use_100px, use_masked)
    print(f"Train: {len(train_loader.dataset):,} | "
          f"Val:   {len(val_loader.dataset):,} | "
          f"Test:  {len(test_loader.dataset):,}")

    model     = build_model()
    optimizer = get_optimizer(model)
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.5, patience=3)

    history = {'train_loss': [], 'val_loss': [],
               'train_acc':  [], 'val_acc':  []}

    best_val_f1     = 0.0
    patience_count  = 0
    best_model_path = OUT_DIR + f'cnn_best_{tag}.pth'

    for epoch in range(1, NUM_EPOCHS + 1):
        t0 = time.time()
        train_loss, train_acc, train_f1 = train_one_epoch(
            model, train_loader, optimizer, criterion)
        val_loss, val_acc, val_f1, _, _ = evaluate(
            model, val_loader, criterion)
        scheduler.step(val_f1)

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch:02d}/{NUM_EPOCHS} | "
              f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | "
              f"Time: {time.time()-t0:.1f}s")

        if val_f1 > best_val_f1:
            best_val_f1    = val_f1
            patience_count = 0
            torch.save(model.state_dict(), best_model_path)
            print(f"   Best model saved (val F1: {best_val_f1:.4f})")
        else:
            patience_count += 1
            if patience_count >= PATIENCE:
                print(f"  Early stopping at epoch {epoch}")
                break

    # Test evaluation
    model.load_state_dict(torch.load(best_model_path))
    test_loss, test_acc, test_f1, test_preds, test_labels = evaluate(
        model, test_loader, criterion)
    kappa = cohen_kappa_score(test_labels, test_preds)

    print(f"\nTEST RESULTS ({tag})")
    print(f"  Test Loss:     {test_loss:.4f}")
    print(f"  Test Accuracy: {test_acc:.4f}")
    print(f"  Test Macro F1: {test_f1:.4f}")
    print(f"  Cohen's Kappa: {kappa:.4f}")
    print(f"\nClassification Report:")
    print(classification_report(test_labels, test_preds,
                                target_names=CLASS_NAMES,
                                zero_division=0))

    # Training curves
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle(f'CNN Training History — {tag}', fontweight='bold')
    axes[0].plot(history['train_loss'], label='Train', color='#457B9D')
    axes[0].plot(history['val_loss'],   label='Val',   color='#E63946')
    axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
    axes[0].set_title('Loss');   axes[0].legend()
    axes[1].plot(history['train_acc'], label='Train', color='#457B9D')
    axes[1].plot(history['val_acc'],   label='Val',   color='#E63946')
    axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
    axes[1].set_title('Accuracy'); axes[1].legend()
    plt.tight_layout()
    plt.savefig(OUT_DIR + f'cnn_history_{tag}.png', dpi=150, bbox_inches='tight')
    plt.show()

    # Confusion matrix
    cm = confusion_matrix(test_labels, test_preds)
    fig, ax = plt.subplots(figsize=(6, 5))
    im = ax.imshow(cm, cmap='Blues')
    plt.colorbar(im)
    ax.set_xticks(range(NUM_CLASSES)); ax.set_yticks(range(NUM_CLASSES))
    ax.set_xticklabels(CLASS_NAMES, rotation=30, ha='right', fontsize=9)
    ax.set_yticklabels(CLASS_NAMES, fontsize=9)
    ax.set_xlabel('Predicted'); ax.set_ylabel('True')
    ax.set_title(f'Confusion Matrix — CNN {tag}', fontweight='bold')
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            ax.text(j, i, cm[i, j], ha='center', va='center',
                    color='white' if cm[i, j] > cm.max() / 2 else 'black',
                    fontsize=9)
    plt.tight_layout()
    plt.savefig(OUT_DIR + f'cnn_confusion_{tag}.png', dpi=150, bbox_inches='tight')
    plt.show()

    results = {
        'tag':           tag,
        'test_loss':     test_loss,
        'test_macro_f1': test_f1,
        'test_accuracy': test_acc,
        'cohen_kappa':   kappa,
    }
    pd.DataFrame([results]).to_csv(
        OUT_DIR + f'cnn_results_{tag}.csv', index=False)

    return model, history, results


# RUN — three experiments
model_100,    history_100,    results_100    = train_cnn(master_s1, use_100px=True,  use_masked=False, tag='100px')
model_50,     history_50,     results_50     = train_cnn(master_s1, use_100px=False, use_masked=False, tag='50px')
model_masked, history_masked, results_masked = train_cnn(master_s2, use_100px=True,  use_masked=True,  tag='masked')

# Final comparison
print("\nFINAL COMPARISON: 100px vs 50px vs masked")
print(f"{'Metric':<20} {'100px':>10} {'50px':>10} {'masked':>10}")
for key in ['test_macro_f1', 'test_accuracy', 'test_loss', 'cohen_kappa']:
    print(f"{key:<20} "
          f"{results_100[key]:>10.4f} "
          f"{results_50[key]:>10.4f} "
          f"{results_masked[key]:>10.4f}")


# EXTRACT CNN EMBEDDINGS FOR GNN
class AllCellDataset(Dataset):
    def __init__(self, df, use_100px=True):
        self.df        = df.reset_index(drop=True)
        self.path_col  = 'path_100' if use_100px else 'path_50'
        self.transform = get_transforms(IMG_SIZE_100 if use_100px else IMG_SIZE_50)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = Image.open(row[self.path_col]).convert('RGB')
        return self.transform(img), row['label']


def extract_embeddings(model, master_df, use_100px=True):
    tag = '100px' if use_100px else '50px'
    print(f"\nExtracting embeddings — {tag}")

    all_ds     = AllCellDataset(master_df, use_100px)
    all_loader = DataLoader(all_ds, batch_size=BATCH_SIZE,
                            shuffle=False, num_workers=2, pin_memory=True)

    embeddings_list = []

    def hook_fn(module, input, output):
        embeddings_list.append(output.squeeze(-1).squeeze(-1).cpu())

    hook = model.avgpool.register_forward_hook(hook_fn)
    model.eval()
    with torch.no_grad():
        for i, (imgs, _) in enumerate(all_loader):
            _ = model(imgs.to(DEVICE))
            if i % 50 == 0:
                print(f"  Batch {i}/{len(all_loader)}")
    hook.remove()

    node_features = torch.cat(embeddings_list, dim=0)
    save_path     = OUT_DIR + f'gnn_node_features_{tag}.pt'
    torch.save(node_features, save_path)
    return node_features


# GNN embeddings use Strategy 1 models
emb_100 = extract_embeddings(model_100, master_s1, use_100px=True)
emb_50  = extract_embeddings(model_50,  master_s1, use_100px=False)
# Out:
# Strategy 1 (100px / 50px CNN)
# Total: 28,379
# split
# train    21000
# val       4500
# test      2879
#
# Class distribution:
# label
# 0    9688
# 1    9393
# 2    9298
#
# Strategy 2 (masked CNN)
# Total: 30,000
# split
# train    21000
# val       4500
# test      4500
#
# Strategy 1 dataset sizes
#   100px: Train 21,000 | Val 4,500 | Test 2,879
#   50px: Train 21,000 | Val 4,500 | Test 2,879
#
# Strategy 2 dataset sizes (masked)
#   masked 100px: Train 21,000 | Val 4,500 | Test 4,500
#
#   100px batch shape:  torch.Size([4, 3, 224, 224])
#   50px batch shape:   torch.Size([4, 3, 140, 140])
#   masked batch shape: torch.Size([4, 3, 224, 224])
# Training CNN — 100px
# Train: 21,000 | Val:   4,500 | Test:  2,879
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 197MB/s]
# Epoch 01/30 | Train Loss: 0.7387 | Train Acc: 0.7047 | Val Loss: 0.4877 | Val Acc: 0.8413 | Time: 194.6s
#    Best model saved (val F1: 0.8411)
# Epoch 02/30 | Train Loss: 0.3848 | Train Acc: 0.8759 | Val Loss: 0.3454 | Val Acc: 0.8978 | Time: 118.0s
#    Best model saved (val F1: 0.8976)
# Epoch 03/30 | Train Loss: 0.2546 | Train Acc: 0.9224 | Val Loss: 0.3132 | Val Acc: 0.9087 | Time: 117.8s
#    Best model saved (val F1: 0.9084)
# Epoch 04/30 | Train Loss: 0.1617 | Train Acc: 0.9490 | Val Loss: 0.3262 | Val Acc: 0.9051 | Time: 118.0s
# Epoch 05/30 | Train Loss: 0.1004 | Train Acc: 0.9674 | Val Loss: 0.3545 | Val Acc: 0.9027 | Time: 119.2s
# Epoch 06/30 | Train Loss: 0.0762 | Train Acc: 0.9772 | Val Loss: 0.3687 | Val Acc: 0.8993 | Time: 119.7s
# Epoch 07/30 | Train Loss: 0.0684 | Train Acc: 0.9799 | Val Loss: 0.4604 | Val Acc: 0.8993 | Time: 117.6s
# Epoch 08/30 | Train Loss: 0.0411 | Train Acc: 0.9889 | Val Loss: 0.4113 | Val Acc: 0.9062 | Time: 117.2s
#   Early stopping at epoch 8
#
# TEST RESULTS (100px)
#   Test Loss:     0.2800
#   Test Accuracy: 0.9194
#   Test Macro F1: 0.9144
#   Cohen's Kappa: 0.8773
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Tumor       0.95      0.94      0.95      1188
#       DCIS_1       0.91      0.94      0.93       893
#       DCIS_2       0.88      0.86      0.87       798
#
#     accuracy                           0.92      2879
#    macro avg       0.91      0.91      0.91      2879
# weighted avg       0.92      0.92      0.92      2879
# Training CNN — 50px
# Train: 21,000 | Val:   4,500 | Test:  2,879
# Epoch 01/30 | Train Loss: 0.8828 | Train Acc: 0.5984 | Val Loss: 0.6998 | Val Acc: 0.7144 | Time: 147.3s
#    Best model saved (val F1: 0.7144)
# Epoch 02/30 | Train Loss: 0.6045 | Train Acc: 0.7637 | Val Loss: 0.5622 | Val Acc: 0.7889 | Time: 59.3s
#    Best model saved (val F1: 0.7880)
# Epoch 03/30 | Train Loss: 0.4266 | Train Acc: 0.8448 | Val Loss: 0.5065 | Val Acc: 0.8187 | Time: 58.1s
#    Best model saved (val F1: 0.8188)
# Epoch 04/30 | Train Loss: 0.2869 | Train Acc: 0.8995 | Val Loss: 0.5074 | Val Acc: 0.8176 | Time: 57.4s
# Epoch 05/30 | Train Loss: 0.1794 | Train Acc: 0.9414 | Val Loss: 0.5643 | Val Acc: 0.8053 | Time: 58.2s
# Epoch 06/30 | Train Loss: 0.1275 | Train Acc: 0.9588 | Val Loss: 0.6244 | Val Acc: 0.7967 | Time: 57.8s
# Epoch 07/30 | Train Loss: 0.1104 | Train Acc: 0.9639 | Val Loss: 0.5727 | Val Acc: 0.8118 | Time: 58.3s
# Epoch 08/30 | Train Loss: 0.0698 | Train Acc: 0.9811 | Val Loss: 0.5993 | Val Acc: 0.8256 | Time: 58.0s
#    Best model saved (val F1: 0.8254)
# Epoch 09/30 | Train Loss: 0.0450 | Train Acc: 0.9878 | Val Loss: 0.6721 | Val Acc: 0.8058 | Time: 57.8s
# Epoch 10/30 | Train Loss: 0.0401 | Train Acc: 0.9886 | Val Loss: 0.6511 | Val Acc: 0.8204 | Time: 58.1s
# Epoch 11/30 | Train Loss: 0.0443 | Train Acc: 0.9880 | Val Loss: 0.6725 | Val Acc: 0.8156 | Time: 57.7s
# Epoch 12/30 | Train Loss: 0.0467 | Train Acc: 0.9864 | Val Loss: 0.6778 | Val Acc: 0.8104 | Time: 58.0s
# Epoch 13/30 | Train Loss: 0.0305 | Train Acc: 0.9920 | Val Loss: 0.6490 | Val Acc: 0.8304 | Time: 57.8s
#    Best model saved (val F1: 0.8303)
# Epoch 14/30 | Train Loss: 0.0219 | Train Acc: 0.9939 | Val Loss: 0.6473 | Val Acc: 0.8358 | Time: 57.9s
#    Best model saved (val F1: 0.8351)
# Epoch 15/30 | Train Loss: 0.0207 | Train Acc: 0.9943 | Val Loss: 0.6834 | Val Acc: 0.8300 | Time: 57.8s
# Epoch 16/30 | Train Loss: 0.0196 | Train Acc: 0.9943 | Val Loss: 0.6933 | Val Acc: 0.8369 | Time: 58.2s
#    Best model saved (val F1: 0.8371)
# Epoch 17/30 | Train Loss: 0.0194 | Train Acc: 0.9944 | Val Loss: 0.7229 | Val Acc: 0.8289 | Time: 57.9s
# Epoch 18/30 | Train Loss: 0.0181 | Train Acc: 0.9945 | Val Loss: 0.7204 | Val Acc: 0.8231 | Time: 58.0s
# Epoch 19/30 | Train Loss: 0.0186 | Train Acc: 0.9946 | Val Loss: 0.7360 | Val Acc: 0.8407 | Time: 57.5s
#    Best model saved (val F1: 0.8400)
# Epoch 20/30 | Train Loss: 0.0235 | Train Acc: 0.9933 | Val Loss: 0.7392 | Val Acc: 0.8311 | Time: 57.8s
# Epoch 21/30 | Train Loss: 0.0234 | Train Acc: 0.9930 | Val Loss: 0.6804 | Val Acc: 0.8340 | Time: 58.1s
# Epoch 22/30 | Train Loss: 0.0234 | Train Acc: 0.9933 | Val Loss: 0.7023 | Val Acc: 0.8336 | Time: 57.2s
# Epoch 23/30 | Train Loss: 0.0281 | Train Acc: 0.9917 | Val Loss: 0.7041 | Val Acc: 0.8333 | Time: 57.4s
# Epoch 24/30 | Train Loss: 0.0208 | Train Acc: 0.9939 | Val Loss: 0.7277 | Val Acc: 0.8429 | Time: 58.0s
#    Best model saved (val F1: 0.8428)
# Epoch 25/30 | Train Loss: 0.0125 | Train Acc: 0.9965 | Val Loss: 0.7546 | Val Acc: 0.8476 | Time: 57.8s
#    Best model saved (val F1: 0.8470)
# Epoch 26/30 | Train Loss: 0.0150 | Train Acc: 0.9956 | Val Loss: 0.7847 | Val Acc: 0.8469 | Time: 58.8s
# Epoch 27/30 | Train Loss: 0.0118 | Train Acc: 0.9968 | Val Loss: 0.7736 | Val Acc: 0.8436 | Time: 58.4s
# Epoch 28/30 | Train Loss: 0.0094 | Train Acc: 0.9973 | Val Loss: 0.7856 | Val Acc: 0.8469 | Time: 57.8s
# Epoch 29/30 | Train Loss: 0.0105 | Train Acc: 0.9969 | Val Loss: 0.9272 | Val Acc: 0.8396 | Time: 57.9s
# Epoch 30/30 | Train Loss: 0.0088 | Train Acc: 0.9976 | Val Loss: 0.7945 | Val Acc: 0.8449 | Time: 58.1s
#   Early stopping at epoch 30
#
# TEST RESULTS (50px)
#   Test Loss:     0.7372
#   Test Accuracy: 0.8479
#   Test Macro F1: 0.8407
#   Cohen's Kappa: 0.7682
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Tumor       0.89      0.88      0.88      1188
#       DCIS_1       0.85      0.88      0.86       893
#       DCIS_2       0.79      0.76      0.78       798
#
#     accuracy                           0.85      2879
#    macro avg       0.84      0.84      0.84      2879
# weighted avg       0.85      0.85      0.85      2879
# Training CNN — masked
# Train: 21,000 | Val:   4,500 | Test:  4,500
# Epoch 01/30 | Train Loss: 0.8580 | Train Acc: 0.6084 | Val Loss: 0.6767 | Val Acc: 0.7244 | Time: 128.8s
#    Best model saved (val F1: 0.7190)
# Epoch 02/30 | Train Loss: 0.5932 | Train Acc: 0.7623 | Val Loss: 0.5881 | Val Acc: 0.7689 | Time: 120.7s
#    Best model saved (val F1: 0.7686)
# Epoch 03/30 | Train Loss: 0.4450 | Train Acc: 0.8299 | Val Loss: 0.5589 | Val Acc: 0.7849 | Time: 121.8s
#    Best model saved (val F1: 0.7859)
# Epoch 04/30 | Train Loss: 0.3180 | Train Acc: 0.8831 | Val Loss: 0.5815 | Val Acc: 0.7860 | Time: 121.1s
#    Best model saved (val F1: 0.7863)
# Epoch 05/30 | Train Loss: 0.2176 | Train Acc: 0.9227 | Val Loss: 0.6246 | Val Acc: 0.7889 | Time: 120.9s
#    Best model saved (val F1: 0.7886)
# Epoch 06/30 | Train Loss: 0.1711 | Train Acc: 0.9395 | Val Loss: 0.6325 | Val Acc: 0.7856 | Time: 121.4s
# Epoch 07/30 | Train Loss: 0.1526 | Train Acc: 0.9463 | Val Loss: 0.8512 | Val Acc: 0.7318 | Time: 121.2s
# Epoch 08/30 | Train Loss: 0.1517 | Train Acc: 0.9454 | Val Loss: 0.7668 | Val Acc: 0.7676 | Time: 122.3s
# Epoch 09/30 | Train Loss: 0.1462 | Train Acc: 0.9484 | Val Loss: 0.6383 | Val Acc: 0.7964 | Time: 120.8s
#    Best model saved (val F1: 0.7967)
# Epoch 10/30 | Train Loss: 0.1478 | Train Acc: 0.9482 | Val Loss: 0.6708 | Val Acc: 0.7773 | Time: 122.1s
# Epoch 11/30 | Train Loss: 0.1507 | Train Acc: 0.9474 | Val Loss: 0.6374 | Val Acc: 0.7960 | Time: 121.6s
# Epoch 12/30 | Train Loss: 0.1556 | Train Acc: 0.9441 | Val Loss: 0.6933 | Val Acc: 0.7642 | Time: 121.9s
# Epoch 13/30 | Train Loss: 0.1632 | Train Acc: 0.9419 | Val Loss: 0.6411 | Val Acc: 0.7964 | Time: 122.3s
# Epoch 14/30 | Train Loss: 0.0798 | Train Acc: 0.9734 | Val Loss: 0.7535 | Val Acc: 0.7936 | Time: 122.0s
#   Early stopping at epoch 14
#
# TEST RESULTS (masked)
#   Test Loss:     0.6423
#   Test Accuracy: 0.8047
#   Test Macro F1: 0.8052
#   Cohen's Kappa: 0.7070
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Tumor       0.88      0.76      0.82      1500
#       DCIS_1       0.81      0.86      0.83      1500
#       DCIS_2       0.74      0.79      0.77      1500
#
#     accuracy                           0.80      4500
#    macro avg       0.81      0.80      0.81      4500
# weighted avg       0.81      0.80      0.81      4500
# FINAL COMPARISON: 100px vs 50px vs masked
# Metric                    100px       50px     masked
# test_macro_f1            0.9144     0.8407     0.8052
# test_accuracy            0.9194     0.8479     0.8047
# test_loss                0.2800     0.7372     0.6423
# cohen_kappa              0.8773     0.7682     0.7070
#
# Extracting embeddings — 100px
#   Batch 0/444
#   Batch 50/444
#   Batch 100/444
#   Batch 150/444
#   Batch 200/444
#   Batch 250/444
#   Batch 300/444
#   Batch 350/444
#   Batch 400/444
#
# Extracting embeddings — 50px
#   Batch 0/444
#   Batch 50/444
#   Batch 100/444
#   Batch 150/444
#   Batch 200/444
#   Batch 250/444
#   Batch 300/444
#   Batch 350/444
#   Batch 400/444

# %%
import os
print(os.path.exists(master_s2['path_100_masked'].iloc[0]))
# Out:
# False
